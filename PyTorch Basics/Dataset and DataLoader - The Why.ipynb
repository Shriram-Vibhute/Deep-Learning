# %% [markdown]
# ## `Dataset` and `DataLoader`: The Why?
# > Loading entire datasets into memory at once can cause problems like memory overflow and slow processing. Dataset and DataLoader classes solve these issues by:
# > 1. Loading data in smaller batches to prevent memory overflow
# > 2. Using parallel processing to speed up computations.
#
# These tools help us work with large datasets more efficiently.

# %%
# Importing necessaey libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import torch
from torch.utils.data import Dataset, DataLoader

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Generate random data for 100 students
n_students = 1000

# Generate features
cgpa = np.random.uniform(5.0, 10.0, n_students)  # CGPA between 5.0 and 10.0
iq = np.random.normal(100, 15, n_students)  # IQ with mean 100 and std 15
marks_12th = np.random.uniform(60, 100, n_students)  # 12th marks between 60 and 100
marks_10th = np.random.uniform(60, 100, n_students)  # 10th marks between 60 and 100

# Generate placement status (binary)
# Higher probability of placement for students with better scores
placement_prob = (cgpa/10 * 0.3 + iq/150 * 0.3 + marks_12th/100 * 0.2 + marks_10th/100 * 0.2)
placed = np.random.binomial(1, placement_prob)

# Create DataFrame
student_data = pd.DataFrame({
    'CGPA': np.round(cgpa, 2),
    'IQ': np.round(iq),
    'Marks_12th': np.round(marks_12th, 2),
    'Marks_10th': np.round(marks_10th, 2),
    'Placed': placed
})

print("Sample of generated student data:")
student_data.head()
# Out:
# Sample of generated student data:
#    CGPA     IQ  Marks_12th  Marks_10th  Placed
# 0  6.87  103.0       98.86       75.51       0
# 1  9.75   80.0       73.25       92.14       1
# 2  8.66  106.0       79.28       96.07       1
# 3  7.99  109.0       67.84       68.14       0
# 4  5.78  108.0       84.43       62.68       1

# %%
# Shape of the dataset
student_data.shape
# Out:
# (1000, 5)

# %%
# Splitting the data
X = student_data.drop(columns=['Placed']),
y = student_data['Placed']

# %%
# Building a Dataset Class
class CustomDataset(Dataset):
    def __init__(self, features: np.array, labels: np.array) -> None:
        """
            In this method, you write an operation which loads the data from any local/cloud storage
        """
        # The data we are getting is directly provided by the user through features and labels
        self.features = torch.tensor(features, device='cpu', requires_grad=False)
        self.labels = torch.tensor(labels, device='cpu', requires_grad=False)

    def __len__(self) -> torch.int32:
        return len(self.features)

    def __getitem__(self, index):
        """
            If you want to apply any kind of transformations then you can apply here
            Transformation:
                Tabular Data:
                    - Scaling
                    - Encoding
                    - Missing Values
                    - Others

                Image Data:
                    - Normalizing the pixels
                    - Resizing the image
                    - Data Augumentation
                    - RGB to black and white transformation
                
                Textual Data:
                    - Embedding / Encoding
                    - Stop Word removel
                    - Lemitization
                    - Other internal preprocessing steps
        """
        # Transformers - Scaling
        # TODO: Mentioning StandardScaler which is entire dataset oriented transformation and not the perticular row specific, because of which we are transforming our data multiple times through standardscaler (Unnecessary computations)
        scaler = StandardScaler()
        self.features = torch.tensor(scaler.fit_transform(self.features.cpu().numpy()), device='cpu')

        # Here you can mention the return the data however you want but the way you have mentioned here simillarly you have to access it while loading the data for training
        return self.features[index], self.labels[index]

# %%
# Creating an object of dataset class
dataset = CustomDataset(
    features=np.array(X[0]),
    labels=np.array(y)
)

# %%
# Finding the length of the dataset
len(dataset)
# Out:
# 1000

# %%
# Accessing a row
index = int(input("Enter the index: "))
print(f"Features at index {index}:", dataset[index][0])
print(f"Labels at index {index}:", dataset[index][1])
# Out:
# Features at index 400: tensor([-1.3228,  0.1017, -1.2777,  1.5235], dtype=torch.float64)
# Labels at index 400: tensor(1, dtype=torch.int32)

# %%
# Creating a DataLoader object
dataloader = DataLoader(
    dataset=dataset,
    batch_size=2,
    shuffle=True, # Will be False for data like Time Series
    pin_memory=True,
    num_workers=0 # If you mention more than zero workers then you will not be able to print the data
)

# Returning the generator
dataloader

# %%
for batch_features, batch_labels in dataloader:
    print(batch_features, batch_labels)
    print("-" * 50)
# Out:
# tensor([[-0.1104, -0.2355, -0.2085,  0.3630],
#         [-0.9529, -0.4378,  0.9058,  0.6808]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.8502,  0.1691, -1.0793, -0.7931],
#         [-0.3776,  0.9110, -1.1477, -0.5084]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.2116, -0.7750, -0.9606, -1.5466],
#         [ 0.0882,  0.9110,  0.2066,  0.2609]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.8828, -0.7750, -1.5186, -0.0317],
#         [ 1.4239,  2.5295, -1.4467,  0.2967]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.4598, -0.3029, -0.4597,  0.2224],
#         [-1.3571, -0.7750, -0.9736,  0.4268]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.4923,  0.5738, -1.5082,  0.3499],
#         [-0.5077,  0.1017, -0.5759,  0.8284]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.0883,  0.3040, -0.4450,  1.2746],
#         [-0.7886,  0.1691, -0.4797,  0.4407]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.2801,  0.1017, -1.2820, -0.5887],
#         [ 0.3964,  0.1017, -0.4286, -1.1528]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.0214,  0.6412, -0.6547, -0.5861],
#         [-0.4598,  0.3040, -1.6728, -0.8786]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0831,  0.2366,  0.8183,  1.5139],
#         [ 0.2937,  0.6412, -0.4606, -1.1825]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1293,  1.1133, -1.1980, -1.3030],
#         [-0.4872, -0.3029,  0.0454, -1.4541]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.6927, -0.2355,  0.7343, -0.9389],
#         [ 0.4170, -1.1797,  0.8599,  1.0642]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1499, -0.6401, -0.3098,  0.4416],
#         [-0.3091,  0.4389, -0.7691,  0.3848]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.6585, -0.7750,  0.1425,  1.1480],
#         [ 1.1225, -0.7750,  1.4439,  0.4075]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.5745,  1.5179,  1.5869, -0.7040],
#         [-1.3845, -0.5727,  1.5245,  0.5892]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.0403, -1.0448,  0.4830, -0.4630],
#         [ 1.2801,  0.3715,  0.9665,  0.2958]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.3280, -0.3029, -0.4996,  1.0851],
#         [-0.3639, -1.7192, -0.2215, -0.3390]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.3160, -0.0332,  0.4700,  1.1201],
#         [-1.5900, -0.1006, -0.6036, -1.6042]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.7338, -1.1122, -0.2648, -0.8446],
#         [ 1.3760,  1.1133,  0.6381,  0.8913]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.6636,  0.3040,  1.0783, -1.1092],
#         [-0.9598,  0.4389, -0.9242, -0.6446]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.4940,  0.7761,  0.6346,  1.2362],
#         [-1.5763, -0.1681,  1.6848, -1.0402]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.9033, -1.2471, -1.6416,  0.2539],
#         [ 0.8759,  0.5738,  1.6051, -1.6173]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.1995,  0.7761, -0.8471, -1.2218],
#         [ 0.3622, -0.2355, -0.2553, -0.2735]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.6105,  0.4389,  1.0878,  0.3857],
#         [ 1.1225, -1.4494, -0.0256, -1.6435]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.1721, -0.6401,  1.5860, -0.4176],
#         [-0.6105,  1.5179,  0.3842, -1.1284]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.6379,  0.2366, -0.0794, -1.0768],
#         [ 0.1156, -1.9889,  1.0081, -0.9188]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.5472, -0.3029, -0.9840,  0.9655],
#         [ 0.7869,  1.3831,  0.5393,  1.3008]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.3897, -0.5053, -0.9528,  1.7627],
#         [ 1.1020, -0.3029,  0.8824, -1.1965]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5694,  2.4621, -0.4216, -0.8717],
#         [ 0.0403,  0.1017, -0.0560, -0.3757]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.2749, -0.5053,  0.2958,  0.5953],
#         [-0.7954,  0.1017,  0.3019, -0.4822]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.9187,  1.0459, -0.0066, -0.3643],
#         [ 0.6841,  0.2366,  0.4527,  0.4992]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.2817,  0.3715, -0.6226, -1.1109],
#         [-0.3433, -1.1122, -1.6737,  0.9856]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7115,  0.5738,  1.0930,  0.3063],
#         [-0.1721, -1.1122, -1.5125,  0.6285]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.1927, -1.3820,  0.5324, -0.5346],
#         [-0.2406, -0.7076, -0.6123, -0.4386]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.2869,  0.7761, -1.0498,  0.2617],
#         [ 0.5471, -0.7076, -1.0134,  1.4117]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.4718, -1.0448, -0.8696,  0.0251],
#         [-1.1995, -0.5727, -1.0871,  1.3025]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.4803, -1.5169, -1.7040,  1.7356],
#         [-1.4530, -1.1797, -0.4312,  0.5473]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.5968,  0.5738,  0.9570, -1.5038],
#         [ 0.4444,  0.1017, -0.4710,  0.5708]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.7201, -1.0448, -0.1149,  0.8380],
#         [-1.0762, -0.1681, -0.9649,  0.7743]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.3965, -2.5285, -1.1928,  1.4955],
#         [-0.8365,  0.0343,  1.1892,  0.3796]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.1036, -0.1006,  0.0827, -0.2788],
#         [ 0.5745,  1.3156,  1.2516,  1.6780]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.5746, -1.4494, -0.5603,  1.0843],
#         [-1.1516,  0.7087,  1.5730, -0.2238]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.5831, -1.1122,  0.1321,  1.1655],
#         [-0.0762, -0.9773,  0.5116, -0.1225]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.6157, -1.1797, -0.4268,  1.1681],
#         [-0.6995, -0.5727, -0.9251,  1.3846]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5009,  1.4505,  1.6233,  0.7490],
#         [ 0.4375, -0.8425,  1.2273, -0.1757]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.5403, -1.1122, -1.2890,  0.3639],
#         [-0.3091, -1.1797,  0.4761, -1.3091]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.9307, -0.7750,  1.6684, -1.4462],
#         [-0.8639, -0.6401, -1.1521,  0.1351]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7321,  0.0343,  1.0211,  1.6702],
#         [-0.9529, -1.3820, -0.5343,  1.0851]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.2749,  1.5179,  0.9994, -0.9799],
#         [-0.7201,  0.0343,  0.4960, -0.9712]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5900,  0.2366, -0.1695,  0.0749],
#         [-1.1584, -0.7750,  0.7083,  1.1943]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7458,  0.1017, -0.2934, -1.2646],
#         [-0.8913,  0.8435,  0.3677,  0.9507]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.2886, -0.0332,  0.6225, -0.0971],
#         [-1.2749,  0.6412, -1.1339,  0.3150]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.6157,  0.9784, -1.3054,  0.2460],
#         [ 0.9924,  0.6412,  1.6917,  0.3482]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.2337, -1.3145, -0.6417,  0.9096],
#         [-1.4187, -1.7192,  0.6788,  1.5628]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.6447,  0.5063,  0.5159, -1.1764],
#         [-0.7612, -0.5727,  1.3287, -0.7285]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0077,  1.6528,  0.6918, -0.9214],
#         [-1.1036,  0.5738,  0.0489,  1.4789]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.4940,  1.5179, -1.3912, -1.4078],
#         [ 0.9033, -0.2355,  1.6112,  0.0295]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.4872,  0.9784,  0.2499, -0.8393],
#         [-0.4187, -1.3820, -0.8098,  1.0877]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.0077,  0.3715,  0.8850,  0.1683],
#         [ 0.0677,  2.0575,  1.6328,  0.2556]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.3228,  0.1017, -1.2777,  1.5235],
#         [-0.3639,  1.7877,  0.8946, -1.4383]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.3212,  0.2366, -0.7119,  0.2207],
#         [ 1.6568,  0.1017,  1.2507,  1.0755]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.2527, -0.5053,  1.3477,  1.1157],
#         [ 0.7321,  0.1017, -0.1192, -1.5859]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.1225, -0.2355,  0.8114, -0.6516],
#         [-1.3023, -0.2355,  0.3842,  1.1366]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0351,  0.3715, -1.6208,  1.4361],
#         [ 0.4855, -1.7192,  0.0983,  0.4137]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.1773, -0.2355, -1.7014,  0.0181],
#         [-0.4187, -0.7750,  1.3867, -1.5038]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0214, -0.7076, -1.4692,  1.3733],
#         [ 0.8485,  1.6528, -1.1131,  1.5427]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.2458, -0.8425,  1.0592,  0.7193],
#         [ 1.4034,  0.9784, -0.2587, -0.7765]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.2269, -0.1681,  1.6285,  0.9105],
#         [ 1.1294,  0.4389,  1.1389,  0.3098]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.9787, -1.0448, -0.4294,  0.9280],
#         [-0.1858,  1.8551,  0.0359, -1.0367]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5831, -1.1122, -1.5134,  0.3988],
#         [ 0.4923, -0.2355, -0.9129,  0.5053]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.3502, -0.3704,  1.6077, -0.0203],
#         [-1.5489,  0.3715,  0.3833, -0.0124]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0557,  0.9110, -0.2267, -0.4770],
#         [-0.5762,  0.1691,  0.0948,  0.3010]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.1362,  1.1133,  1.6484, -1.6654],
#         [ 1.2390,  0.3040,  0.9032,  0.6320]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.0814, -0.5727,  0.7256, -1.6933],
#         [-1.2543,  0.3715, -1.6798, -0.8193]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.2184,  0.3040, -0.1565, -0.7162],
#         [ 1.0266, -0.5053, -0.7881, -0.7529]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.8143, -0.3704, -0.8306,  0.5438],
#         [ 1.4239,  0.4389,  1.6311, -0.5171]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.9118, -0.3704,  0.8521,  1.4815],
#         [ 0.1430, -0.0332,  1.1225,  1.0135]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5215, -0.2355,  1.0887, -0.5206],
#         [-1.4324,  1.5854, -0.0716,  0.0583]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.5197, -0.3704, -0.7812, -1.3632],
#         [-1.2680,  0.1691, -1.6009, -0.9118]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.3365,  0.7761, -1.4640,  1.3287],
#         [-0.4324,  1.4505,  0.5610, -0.2255]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.4102,  1.3156, -0.2743, -0.3696],
#         [ 0.9581, -1.6517,  0.0350, -0.4595]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.2200, -0.7076, -1.6685,  0.1980],
#         [-0.7680,  0.5738, -1.4917, -0.5512]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.1636,  0.5063, -0.9381, -1.0585],
#         [-0.2611,  0.9784,  1.1441, -0.9607]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.6568,  0.7761, -0.1547,  1.6841],
#         [ 0.5540,  0.6412, -1.3436, -0.0937]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.0197,  1.3156, -1.7032,  0.0871],
#         [ 0.4718, -1.0448,  0.6468, -1.3152]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.4529, -0.1681, -0.7180, -0.2858],
#         [-1.0831,  1.0459,  1.3426, -1.1764]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.7612,  0.5738, -1.0871,  0.1788],
#         [ 0.8417,  0.5738,  1.6103, -0.5302]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5420,  0.3715,  0.1598, -1.2104],
#         [ 1.0472, -0.3704, -1.2127, -0.0124]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1567, -0.1681, -0.5213, -1.5361],
#         [ 0.8828,  1.4505,  1.6424,  1.6946]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.7201, -0.2355, -1.4909,  1.6658],
#         [ 1.4034,  0.7087, -1.5082,  1.4606]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.4718,  1.9226, -0.2345,  0.1648],
#         [-1.0899,  0.9784, -1.4614, -0.9520]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0831,  0.5738,  0.0030,  1.0458],
#         [-0.4187, -0.8425, -1.7032, -0.7721]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.3776, -0.3704,  0.0445, -1.0699],
#         [-0.2611, -0.1006,  0.6017, -0.9310]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.4872,  1.4505,  0.6234,  0.2757],
#         [-0.0282, -0.5727,  1.6432,  1.5278]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7937,  0.1017, -1.2422, -0.0840],
#         [-1.4393, -0.3704, -0.6755, -0.8900]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.1926, -1.2471, -0.3644,  0.4687],
#         [-0.1310, -0.3704,  1.3330, -0.5311]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.3297,  1.4505,  0.9318,  1.3549],
#         [ 0.1704, -0.9099,  0.3911,  1.0956]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.6448, -1.2471, -1.0039,  0.3971],
#         [-1.3639, -1.1122,  0.0905, -1.6173]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.0061, -1.9215, -1.5732,  0.2015],
#         [-0.6516, -0.8425,  1.3711,  0.3281]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7252, -1.7192,  1.5765,  0.0434],
#         [ 1.2732,  1.1133, -0.1747, -0.8332]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1704, -0.4378, -0.8696, -1.2820],
#         [-1.0557, -1.1797,  1.0731, -0.2080]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.8296,  1.8551, -1.3548, -1.4183],
#         [-0.6790, -0.1006, -0.3324, -0.4979]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5557, -0.4378, -0.9311,  1.6509],
#         [-0.7406,  0.4389, -0.8713, -0.4482]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.3228,  0.4389, -1.5836, -0.3137],
#         [-1.2680,  0.6412, -0.5568,  0.9061]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0694,  0.4389, -1.0178, -1.3327],
#         [-0.4118,  1.1133, -0.6538,  0.2792]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0488, -1.1797,  1.6640,  0.0731],
#         [-0.8639, -0.3704,  0.9414,  1.0816]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5215, -0.8425, -1.1295, -0.4953],
#         [ 1.6225, -1.6517, -0.7015, -1.0568]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.4101, -0.6401,  1.7021,  0.9210],
#         [-0.1378, -0.7076, -0.5932, -0.9921]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.4513, -0.1006, -1.6780,  1.6579],
#         [-0.6721,  1.1133, -0.6348,  0.6608]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.3964, -0.0332, -0.8315, -1.5650],
#         [ 0.2732,  0.1017, -1.4016,  1.2982]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.7543,  0.2366, -1.4865,  1.2510],
#         [ 1.2321, -1.1797,  0.4899,  1.0921]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.0198, -3.0005,  0.7334, -0.2290],
#         [ 0.7389, -0.9773, -0.3289, -0.4211]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.4118,  0.3040, -0.0308,  0.3569],
#         [-0.2748,  0.5063, -0.2163,  1.3794]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.8485, -1.1797, -1.6954, -1.2227],
#         [ 0.8211,  0.1691,  0.6918, -0.7974]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.2886,  1.2482, -1.5715,  0.6101],
#         [-0.9461, -1.9215,  1.3963, -0.3224]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.5077,  0.6412,  0.5679,  1.0004],
#         [ 0.1156,  0.5738, -0.6911, -0.6001]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0694,  0.8435,  1.5895, -0.6892],
#         [-0.0967, -1.6517,  0.3634,  0.6616]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.5951, -1.5843, -1.4268,  1.5820],
#         [ 0.6567,  1.1807,  1.2906, -0.1784]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.9940,  0.1017,  0.0021,  0.7533],
#         [-0.7475,  0.5738, -0.4537, -1.0157]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.8502, -0.1006,  1.6545, -0.2342],
#         [ 0.5540, -0.3704,  1.6909, -1.0349]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.8844, -0.5053, -1.0186,  0.6223],
#         [ 0.5060,  1.9900,  0.7663, -1.0358]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.2390,  1.1133, -1.5524, -1.3074],
#         [-1.4804, -0.0332,  0.9717, -1.6863]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.4239, -1.5843, -1.5273, -1.1257],
#         [ 1.0677, -0.3029,  0.7993,  1.6492]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.3159, -0.9099,  1.5895,  1.7426],
#         [ 0.9650, -0.9099, -0.6859,  0.6957]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.0472, -0.5053, -0.6850,  0.8101],
#         [ 0.3279, -1.3145,  0.5246, -0.0937]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.6037, -0.3704,  0.6268,  0.3228],
#         [ 1.4308, -0.3704,  0.4059,  0.6407]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.7132, -0.4378, -0.6850, -0.1915],
#         [ 0.7663,  1.2482,  0.8634,  0.8214]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.2800,  1.5854,  1.0168, -0.7608],
#         [-1.3913, -0.3704,  1.4058, -0.5224]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.9735, -1.0448,  0.0913,  0.7289],
#         [-0.2132, -0.0332, -0.6876, -0.5826]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.7954, -1.1122, -1.3011,  1.1419],
#         [-0.2474, -0.4378, -0.3766, -0.6298]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.6225, -0.2355, -1.3427, -1.3903],
#         [-1.5968, -0.5727, -0.4649, -1.3694]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5215, -0.9773, -1.2526,  0.5892],
#         [ 0.5266,  0.1017,  1.1502,  1.6230]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.0609, -0.0332,  1.2143, -0.3198],
#         [-0.4324, -0.5727, -0.7058,  1.2013]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.8896, -1.1122, -0.5395,  0.6442],
#         [ 0.1567, -0.2355, -1.0256, -0.1015]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.1652, -0.8425, -0.5022,  0.7446],
#         [ 0.0951,  0.5063,  0.9128,  0.9402]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.3571, -0.0332,  1.2273,  1.2379],
#         [-0.4940, -1.7192, -1.0628, -0.9136]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5968,  2.1923,  0.6407, -1.5999],
#         [ 0.2184,  0.5063, -0.8531, -0.4141]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7937, -0.3704,  0.5939,  0.3132],
#         [ 0.3964, -0.1006, -0.7180, -1.4270]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.2201, -0.5053,  1.2819,  1.3191],
#         [-1.2406, -1.0448, -0.2544,  1.1672]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.8143, -0.6401, -0.6608,  0.5464],
#         [ 0.4375, -0.0332, -0.0412, -0.3914]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.6499,  0.1017,  1.4110,  0.4416],
#         [ 0.4923,  1.3156, -0.5282, -1.4872]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.7458,  0.7087, -1.6668,  1.1541],
#         [-0.3365, -2.6633, -1.0446,  0.4180]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.8228,  0.2366,  0.0636, -1.0838],
#         [-1.5557, -1.6517,  1.1571,  1.7383]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.5471,  1.1133, -1.4553, -0.2604],
#         [ 0.3553, -0.7750,  0.9162, -0.2159]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.0540,  0.1691, -1.1720,  0.9620],
#         [ 1.5677,  0.1017, -0.2839,  0.9769]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.5077,  0.5738, -0.3384, -0.1321],
#         [-1.3845, -0.5053,  0.1477,  0.4870]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.5472, -0.1681, -1.1538,  0.9472],
#         [ 0.1430, -0.4378,  0.6572,  0.9411]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.9118,  0.1691,  1.4717, -0.7730],
#         [-1.4119, -0.1681,  0.0134,  0.2085]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.4170, -1.4494,  1.5661, -0.9319],
#         [-0.3981,  0.5738, -0.8540, -1.1537]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.4581,  0.7761, -1.3531, -0.1749],
#         [-0.1789,  0.8435,  1.4743,  1.5558]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.4923, -0.7750,  1.0445, -0.3181],
#         [ 0.3827, -0.1681, -1.6893,  1.6588]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1841,  1.4505, -1.3574,  1.7444],
#         [ 0.9102, -0.4378, -1.2145, -0.5861]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.6088,  1.5179, -1.3254, -0.3154],
#         [ 1.0609,  1.1807,  0.5627, -1.1039]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.2937, -1.1122,  0.3123,  1.2449],
#         [-1.2817,  0.5063, -1.5567,  0.5001]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.9787, -0.1006,  1.3945, -1.3606],
#         [ 1.1842,  0.6412,  0.4735, -1.2288]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.1995,  0.9784, -0.2977, -0.6656],
#         [ 1.0677,  2.3947,  1.3200,  0.0487]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.6979, -0.4378, -0.8696, -1.3571],
#         [ 1.1020, -0.1006,  0.0212, -0.4674]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.5883, -0.7076,  1.6103,  0.9297],
#         [-1.0899, -0.6401,  0.0766, -0.6472]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.3622,  2.4621, -0.6348, -0.3443],
#         [ 0.1773,  1.7877,  0.6970, -0.9057]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.3485,  0.5063,  1.4613,  0.1927],
#         [ 0.0745, -1.3820, -0.0135,  0.7132]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.1995, -0.1006,  1.5210, -0.9537],
#         [ 1.5335,  0.7087,  1.4318, -0.4613]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.2047,  0.9110, -1.5463,  1.1620],
#         [ 0.4855,  1.0459,  0.3946,  0.6398]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.4461,  0.3715,  0.8668,  0.8232],
#         [ 1.3623, -1.7192, -0.1045,  0.3150]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.4119,  0.3040,  1.0410,  1.1646],
#         [-0.9735,  1.2482,  0.9639,  0.6442]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.6036, -0.5727,  0.7369, -1.5859],
#         [-1.1173, -1.2471,  0.8313,  1.3724]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.0403, -0.7750,  0.7421,  1.1506],
#         [-1.3434,  0.9784,  1.6328, -0.8027]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1773, -0.8425,  1.6363,  1.6981],
#         [-1.1584, -0.1006, -0.2431, -0.5687]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.4307,  1.5854, -1.4389, -1.4331],
#         [-1.0351, -0.4378, -0.9831,  1.4161]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.3075,  0.5738, -1.4597, -1.3903],
#         [ 0.5951, -2.8657,  0.6901,  1.7627]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.2543,  0.9110,  0.2733, -1.2008],
#         [ 1.3828, -0.9099, -0.2561,  0.5630]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.2064,  0.3715, -1.0108,  0.7411],
#         [-1.2406,  0.1691,  0.3764,  1.4143]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.4171, -1.5169, -1.3557,  0.5892],
#         [ 0.5197,  0.8435, -1.3436,  1.4510]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.5831, -1.6517,  0.2248,  0.6442],
#         [-1.0968, -0.3029,  1.5739,  0.3325]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.3023,  1.1807, -0.1348, -1.5815],
#         [ 0.0060, -1.5843, -0.1955, -1.3528]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1636,  0.7087,  0.3149, -1.1624],
#         [-0.8981,  0.1017,  0.6771, -0.2858]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1156, -0.1681,  1.6120, -0.6743],
#         [ 1.4924,  0.3040,  0.3071, -0.8306]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.1310, -1.6517, -1.6607, -0.3023],
#         [-0.2132, -0.1681, -0.3948, -0.8944]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.9239, -1.5169, -0.1608, -1.4130],
#         [ 0.7663, -3.0005, -0.7509, -0.7241]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.7406, -0.1006, -1.1443,  0.4224],
#         [ 0.8211,  0.5063,  1.1779, -0.7852]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.4513,  0.1017, -1.6416,  1.1070],
#         [-0.7132,  1.3156,  0.7637,  0.8083]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.3570,  0.3715,  0.2655,  0.3709],
#         [ 0.7321, -0.1681,  1.4457,  1.3305]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.3639,  0.0343, -1.6477, -0.7389],
#         [-1.5831, -0.4378,  1.5878, -0.2980]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.6636, -1.4494,  0.5696,  1.4580],
#         [ 1.5609,  2.5295,  0.5419, -1.6767]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.8759, -0.7076, -1.5611, -0.2613],
#         [-1.0420,  1.1807,  1.4838, -0.9136]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.7269, -1.1797, -0.1643,  0.5726],
#         [ 0.2595,  1.0459,  0.3279,  0.8869]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.5351, -0.7750,  0.3348,  1.3881],
#         [-1.4050,  0.1691, -0.7587, -1.5457]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.4307, -1.2471,  0.7308, -1.1912],
#         [ 1.6842, -1.8541, -0.5117, -0.3495]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.0266, -0.3029, -0.7700, -0.6979],
#         [-0.3433,  1.0459,  0.4804,  1.6632]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.9735, -0.4378, -0.4225, -0.5250],
#         [ 0.0129,  0.4389, -0.6920,  1.6422]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5900,  0.6412, -0.7232, -0.4220],
#         [-1.5215, -1.1797,  0.7057, -0.1356]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.4102, -1.5169, -0.7561,  1.4300],
#         [-0.3091,  1.9900, -0.2041, -1.1118]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7937, -0.9099,  0.4535, -0.8385],
#         [ 0.8074, -2.2587,  0.3487,  0.5787]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.2954,  0.6412, -0.5455, -1.6217],
#         [ 0.7047,  2.1923,  0.5506, -1.1607]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.0472,  0.8435, -0.4849, -1.0463],
#         [ 1.3623,  0.5738,  0.6242,  1.1244]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.9598, -0.7750,  0.0991,  0.6005],
#         [ 0.5814,  1.3831,  1.6328,  0.9987]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7663, -0.9099,  1.0263, -1.0664],
#         [ 1.4239, -0.5727, -0.7457, -1.1764]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.0488,  0.9110, -1.2136,  0.5761],
#         [-0.5557,  0.4389, -1.6494,  1.2397]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.6379,  1.5854, -1.0299,  0.9218],
#         [ 0.8074, -0.5727,  1.5635, -0.7546]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7732,  0.1017, -0.6651,  0.1945],
#         [-0.0625,  0.3040,  0.1572,  1.1821]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.0951, -1.1797,  0.1667,  0.9192],
#         [ 1.1910,  0.4389, -0.8514,  0.6948]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.6431,  1.1807,  1.2602, -1.6828],
#         [-0.6379,  0.1691,  0.3989,  0.9550]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.4034,  0.7761, -1.2760, -0.0159],
#         [-1.1995,  0.1017,  1.1961, -0.0509]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.6105, -2.2587,  0.9414, -0.6219],
#         [ 1.3691,  1.1807, -0.2085,  1.5313]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.5694,  0.1691, -1.6278,  0.4564],
#         [ 0.8896,  0.5063,  1.3772,  0.4023]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.1858, -1.5843,  0.1685,  1.5200],
#         [-0.1378, -0.9099, -1.0550, -0.5625]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.4855, -0.6401,  1.5029,  1.5540],
#         [-0.5762, -1.5169,  0.2074,  0.9061]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.2663,  0.8435, -0.1859, -0.0980],
#         [-1.1653,  0.2366,  1.6787,  1.6649]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1019,  1.4505,  1.7342,  1.5348],
#         [-0.3981, -1.3145,  0.6286,  1.4536]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.8228,  1.7877, -1.1304,  1.4143],
#         [ 0.0471,  0.2366,  1.6398,  1.4938]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.3982, -0.2355,  0.0246, -0.8455],
#         [ 0.3416, -1.5843, -0.8748, -1.3161]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.6174, -2.2587,  1.2386,  0.0609],
#         [ 1.6157, -0.7750, -0.3627,  1.4056]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.6995, -0.1006,  0.6987,  1.3113],
#         [ 1.5540, -1.4494, -0.9155, -0.4560]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.3211,  0.2366,  1.0271,  0.7245],
#         [-1.5009, -0.5053,  0.0411, -0.1504]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.8296, -0.4378, -0.9389, -0.5756],
#         [ 0.3416,  0.1017,  1.0349, -0.3539]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.2527,  2.3272, -0.2050, -0.9598],
#         [ 0.9581, -0.1006,  1.1424, -0.4359]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.5146, -0.8425, -0.7812,  0.9000],
#         [-1.3297,  0.7761, -1.6269, -0.8105]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.9855, -0.6401,  1.7273,  0.5900],
#         [-1.1242,  0.4389, -1.6200,  1.2283]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7047, -0.0332, -0.8696, -0.2072],
#         [-1.4667, -1.4494, -1.7084,  1.4737]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7595, -1.1122,  1.1597, -0.7215],
#         [-0.2817, -0.4378, -0.6946,  0.2539]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.3981,  0.5063,  1.5366,  0.1648],
#         [-0.1721,  0.9784,  1.6016,  0.9035]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.3279,  0.7761,  1.5921, -1.1249],
#         [ 0.3690,  0.5063, -1.0290, -1.0114]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.2748,  0.4389, -1.0316,  0.2827],
#         [-1.1242, -1.1122,  0.3322, -1.6112]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5626,  2.1923,  0.4977, -1.2323],
#         [ 1.3691, -2.0564,  0.5826, -1.0891]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.7116, -0.5727, -0.2960, -0.0299],
#         [ 0.0197,  1.5179,  1.0393,  0.5822]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.3639, -1.4494, -1.0724,  0.8424],
#         [ 1.6157, -0.7750,  1.1978, -1.7186]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5283, -2.1238,  0.7447, -0.2203],
#         [ 1.6157, -0.0332, -1.2448,  0.5892]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.8639,  0.1691, -0.1816,  1.7042],
#         [ 0.1088, -0.6401,  1.4691, -1.6130]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.4787,  0.1691, -1.4623,  0.2993],
#         [-0.6173, -0.7076,  0.5523, -0.9581]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1362, -0.1681,  0.1407,  1.2056],
#         [-0.4529, -0.6401,  0.2924,  1.5575]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.1721,  1.7877,  1.0817, -0.7721],
#         [ 1.2184, -0.3029, -1.4415, -1.5815]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.6431,  0.7761,  1.3772, -0.5276],
#         [-0.1036,  0.1691,  0.6953,  0.1334]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.5061,  1.9226,  1.0531,  1.0912],
#         [ 1.3897,  1.4505, -0.8419, -0.6211]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1019, -0.6401,  0.6710, -1.0410],
#         [ 0.4444,  0.4389, -1.3158, -0.0884]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.3485,  1.1807,  1.7325, -0.9616],
#         [ 0.8965,  1.2482,  1.0895,  1.3680]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.0060,  1.5854, -0.9268,  1.1332],
#         [ 1.0403,  1.2482, -1.6425, -1.4252]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.3896, -0.3029, -0.2804, -1.3013],
#         [ 1.2938,  0.2366,  1.2680,  0.3228]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.1447,  0.3715,  1.6744,  0.6477],
#         [ 0.2115, -0.3029,  0.9292,  1.5392]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.4513,  0.1691, -1.4917,  0.7149],
#         [-1.2680, -0.3029, -0.6469,  0.9349]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.2595,  0.1017, -0.5395, -1.1563],
#         [-0.4529, -2.1238,  0.5878,  1.1017]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7184,  1.1807,  1.0064,  1.1925],
#         [ 0.2869,  0.2366,  0.9708, -0.7948]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.0762, -0.6401, -1.2205, -1.5283],
#         [-0.2474,  2.3947,  0.4483, -1.3615]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# ...
# --------------------------------------------------
# tensor([[-1.6448, -0.3029, -0.1002, -0.9031],
#         [-0.6584,  0.4389, -1.3020,  0.0452]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.6311,  0.9110,  0.0766, -1.2567],
#         [-1.0420,  0.0343, -0.6296, -0.5809]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0557, -1.0448,  1.1632,  0.7001],
#         [-0.3159, -0.9099,  0.4171,  0.2932]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.5814,  1.9900,  0.7421,  1.5156],
#         [ 1.2458, -1.1122,  1.1831, -1.2689]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.6019, -0.8425, -1.4718, -0.6839],
#         [-1.3091, -0.7750, -0.5811,  1.5846]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.0335,  0.0343, -1.2916,  0.8590],
#         [-1.3982,  0.0343, -1.5784,  1.2283]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.4256,  0.3715, -0.0239, -0.8001],
#         [-1.5420,  1.7203,  1.5522,  1.5409]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.0609,  1.0459,  0.4076, -1.5230],
#         [ 1.3760,  1.1133,  1.4587,  1.3261]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.9872, -0.0332,  0.4449,  0.5184],
#         [-1.1653,  0.3040, -1.3895, -0.9878]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.2132,  0.1017, -0.2145, -0.8158],
#         [ 1.3897,  0.4389,  1.2325, -0.5145]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.3074, -0.5053,  0.8313,  1.0450],
#         [-0.6105,  1.7203, -0.5074,  0.2486]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.2406,  0.9110, -1.2820, -0.0343],
#         [ 0.6430, -0.3704, -0.1695,  0.0251]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1910, -0.5053, -1.3115,  1.3881],
#         [-1.6585, -0.3029,  0.0636,  0.5796]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.2321, -1.5169,  0.1789,  0.9018],
#         [ 1.1157,  0.5063, -0.5559,  1.1628]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.3690,  1.7877, -0.8965, -0.6193],
#         [ 1.2732, -0.7076,  1.2958,  1.1235]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.4461, -0.8425, -0.1443, -1.1537],
#         [-0.3913,  0.8435,  1.5592, -0.8603]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.5334, -0.4378,  1.0800, -1.1371],
#         [ 0.8828, -0.3029,  0.6190,  0.8555]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.4992, -0.6401,  0.3747,  0.2242],
#         [-0.7475, -0.7076, -0.5516, -1.2794]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.5899, -0.1006,  1.7160, -0.8786],
#         [ 0.5197,  0.7087, -0.0326, -0.4822]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.6790, -0.0332, -1.3141, -0.4316],
#         [ 0.2115,  0.0343,  0.2092,  1.2467]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.4256,  1.5854,  0.4787,  0.1342],
#         [-0.9529, -0.1006, -0.8384,  0.2416]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.7817,  1.3156,  0.0515,  1.3628],
#         [ 0.2732,  0.3715, -0.0343,  0.6843]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.3434,  0.7761, -0.6365,  0.3167],
#         [ 0.4649,  0.2366,  0.6017, -0.0238]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1910,  0.0343, -0.1218,  1.7688],
#         [-1.2680, -1.1797,  0.3392,  1.5558]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.8502, -0.6401,  0.1693,  0.1211],
#         [-1.0077,  1.5179,  0.9518, -1.6156]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.5266,  0.5063,  0.4431, -1.0961],
#         [-0.9392, -0.5053, -0.1513,  1.2807]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.6225, -0.2355, -0.7067, -0.3792],
#         [ 0.2389,  0.3040, -0.8471, -1.7221]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.1447, -0.3029,  0.7369,  0.7655],
#         [ 0.0814, -1.3145, -0.9432, -0.4831]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.0830, -1.3820, -0.5941,  1.2117],
#         [ 1.5266, -1.3145,  1.2238, -1.2087]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.6225,  0.3715, -1.6070, -0.9494],
#         [ 0.8896, -0.9773,  0.8495, -0.5922]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.4598,  0.1017, -1.0871, -1.4305],
#         [ 1.1910, -3.0680, -1.3548, -1.4375]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.8433,  0.4389, -1.0646,  1.7549],
#         [ 0.8554,  0.7761, -1.3236, -1.2428]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0557,  0.6412,  0.7412, -0.5896],
#         [-1.1584, -0.9773, -0.0577, -0.2578]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.4033, -0.3029, -0.7561, -0.0317],
#         [ 1.1362,  0.1691, -0.1210, -1.0734]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0694, -0.1006, -0.8063,  1.7260],
#         [ 0.0403,  0.3040, -0.7084, -0.1775]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.6225, -1.1122,  0.9327, -0.9825],
#         [ 1.3280, -1.7866, -0.6140, -0.1539]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.0403, -1.7192,  1.6562, -0.7110],
#         [ 0.7115,  0.0343,  1.6216,  0.2923]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.5746, -1.2471, -0.1937, -1.6086],
#         [-1.5420, -0.1681,  0.3036,  1.5671]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.1705,  0.1691, -1.3340, -0.4106],
#         [-0.3570, -1.7866, -1.2136, -0.4813]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.0197, -0.9773, -1.6737,  1.6117],
#         [-0.8570, -0.2355,  1.5722, -1.0873]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.4512,  0.6412, -1.1010,  1.1899],
#         [-0.4940,  0.0343,  0.7663, -1.4794]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.3159,  1.5854,  0.4847,  0.8983],
#         [-0.0967,  1.1133,  1.5652, -0.3355]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7458, -1.7866, -1.6815, -1.4899],
#         [ 1.0951,  0.3040, -0.6703, -0.0186]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.3622,  0.7761,  0.4293, -1.6654],
#         [ 0.4855,  0.7761, -1.0342,  0.7752]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.4530,  1.3831, -0.2466,  1.0877],
#         [-1.5694,  0.4389, -1.0004, -1.3196]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.0266, -0.3029,  0.7499, -0.6490],
#         [ 0.3211, -0.0332, -0.6235,  0.3534]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.6294,  1.1133,  0.4570, -1.1842],
#         [-0.7543, -0.3029,  0.9786,  0.5298]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.4941, -0.1006, -0.8115, -0.6883],
#         [ 1.6431, -1.4494, -0.1270,  1.4501]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.7252,  0.4389, -0.3124, -0.1207],
#         [-1.1242, -1.4494,  1.6926, -1.4872]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.3897,  0.8435,  0.3548,  0.1107],
#         [-0.2132, -0.0332, -1.2214, -1.2681]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.3965, -0.1681, -0.4078, -0.2438],
#         [ 0.8417,  0.9110,  0.5263, -0.8926]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5420,  0.2366,  1.3824, -0.9520],
#         [ 0.9376,  0.4389,  0.6381, -1.3449]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.6242,  1.6528,  0.6372, -0.7503],
#         [ 0.3006, -0.4378, -0.3046, -0.6254]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0283, -0.5053,  1.4829, -1.2524],
#         [-1.4530, -0.9099,  0.6277,  0.6520]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.6995, -0.0332, -0.8072, -0.6254],
#         [-1.5009,  0.8435, -1.6460, -0.3696]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.6242,  0.2366,  0.4622,  0.6913],
#         [ 1.6294,  0.0343, -1.6590, -0.6761]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.5403,  0.4389, -0.9779,  1.6763],
#         [ 0.9787, -0.1681,  0.0792, -0.3530]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.4804,  0.7761, -0.9909, -0.3617],
#         [-1.5626, -0.7076, -0.9970,  1.5418]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5215, -0.0332,  1.0384, -0.6874],
#         [ 0.1225,  0.7761,  0.8305, -0.8411]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.1242,  0.3715,  0.7265, -0.9974],
#         [ 1.6979,  0.2366, -0.9173, -1.3999]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.8280, -0.7750, -0.3506, -0.4831],
#         [ 0.1978,  0.1017,  0.2924,  1.2921]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.3211,  2.2598,  1.6926, -1.6846],
#         [ 1.0609, -0.7750, -0.7292,  1.1873]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.2526,  1.9900, -0.7769,  1.4859],
#         [-0.4803, -1.9889,  1.3313,  0.2774]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.1156,  2.5295,  1.0887, -1.5842],
#         [-0.1926, -0.3029,  0.1485, -0.0544]], dtype=torch.float64) tensor([1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.4392, -0.8425, -0.1175,  1.4222],
#         [ 1.3691,  0.7087, -0.9025,  0.2836]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.8365, -0.0332,  1.3088,  0.3194],
#         [ 0.3211,  0.1017, -1.4441,  0.1875]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.8211, -0.7076, -0.2457, -0.7721],
#         [-0.6721,  1.3156,  1.6016,  0.4573]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.1515, -0.7750, -1.4458,  0.3569],
#         [-0.5351, -0.2355,  0.0896,  0.2958]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.0951, -0.1681, -1.4796,  0.2460],
#         [ 1.2869,  0.3715,  0.0818,  0.1700]], dtype=torch.float64) tensor([0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.5334, -0.1681,  1.7359, -0.7608],
#         [ 0.1773,  1.0459, -0.0568,  1.7339]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.5625, -0.5053,  1.2221,  0.3569],
#         [ 0.0608, -0.2355,  0.7308, -1.5457]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.5215,  0.0343,  1.0263,  0.6276],
#         [-1.0488, -0.3704, -0.3783,  0.8974]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.3913,  1.7877, -0.4121,  1.1567],
#         [-1.1995, -0.6401,  0.4301, -1.4820]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-0.6721, -1.1122, -1.0368, -1.2838],
#         [-0.6721, -0.3704,  0.8582, -0.8262]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 0.2252,  0.4389, -0.4710, -0.0552],
#         [ 1.7321,  1.1807,  0.1780,  0.4914]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.2749,  1.6528, -0.6694, -0.6324],
#         [-1.4187, -0.1006,  1.3850, -1.1746]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0557, -0.6401, -1.6659, -0.2954],
#         [ 1.6910, -2.3261,  0.7828,  0.6852]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[-1.0420, -0.7750, -0.5048, -0.4193],
#         [ 0.8759, -0.7076,  1.1025, -0.3163]], dtype=torch.float64) tensor([0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.1842, -1.1797,  1.6415,  0.6346],
#         [ 1.5746, -0.5053, -0.0924,  0.2067]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 1.5266,  0.5738, -0.9935, -0.1443],
#         [ 1.3623, -0.7750, -0.4199,  0.4530]], dtype=torch.float64) tensor([1, 1], dtype=torch.int32)
# --------------------------------------------------
